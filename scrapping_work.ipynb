# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
url = "https://en.m.wikipedia.org/wiki/World_War_I#cite_note-1"
response = requests.get(url)
print(response)
data = BeautifulSoup(response.content, features= "lxml")
# Out:
# <Response [200]>

# %%
data.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   World War I - Wikipedia\n  </title>\n  <script>\n   document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"X-SEkwpAAEIAAD1P@QgAAABR","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"World_War_I","wgTitle":"World War I","wgCurRevisionId":998443691,"wgRevisionId":998443691,"wgArticleId":4764461,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"World_War_I","wgRelevantArticleId":4764461,"wgIsProbablyEditable":!1,"wgRelevantPageIsProbab
# ...

# %%
a = data.find('div', {'class': 'mw-stack stack-container stack-clear-right'})

# %%
a.prettify()
# Out:
# '<div class="mw-stack stack-container stack-clear-right">\n <div>\n  <table class="infobox vevent" style="width:25.5em;border-spacing:2px;">\n   <tbody>\n    <tr>\n     <th class="summary" colspan="2" style="background-color:#C3D6EF;text-align:center;vertical-align:middle;font-size:110%;">\n      World War I\n     </th>\n    </tr>\n    <tr>\n     <td colspan="2" style="text-align:center;border-bottom:1px solid #aaa;line-height:1.5em;">\n      <a class="image" href="/wiki/File:WWImontage.jpg">\n       <img alt="WWImontage.jpg" data-file-height="828" data-file-width="799" decoding="async" height="311" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/20/WWImontage.jpg/300px-WWImontage.jpg" width="300"/>\n      </a>\n      <br/>\n      Clockwise from the top:\n      <div class="hlist hlist-separated">\n       <ul>\n        <li>\n         The road to\n         <a href="/wiki/Bapaume" title="Bapaume">\n          Bapaume\n         </a>\n         in the aftermath of the\n         <a hre
# ...

# %%
b = data.find_all('tr')

# %%
c = data.find('span', {"class":"datasortkey"})

# %%
c
# Out:
# <span class="datasortkey" data-sort-value="France"><span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931958%29.svg/23px-Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931958%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931958%29.svg/35px-Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931958%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931958%29.svg/45px-Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931958%29.svg.png 2x" width="23"/> </span><a href="/wiki/French_Third_Republic" title="French Third Republic">France</a></span>

# %%
c["data-sort-value"]
# Out:
# 'France'

# %%
c('span')
# Out:
# [<span class="flagicon"><img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931958%29.svg/23px-Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931958%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931958%29.svg/35px-Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931958%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931958%29.svg/45px-Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931958%29.svg.png 2x" width="23"/> </span>]

# %%
#from PIL import Image
from io import BytesIO
urls = "//upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931958%29.svg/23px-Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931958%29.svg.png"
trys = requests.get('https:'+urls)
img = Image.open(BytesIO(trys.content))
img
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-b93bb112bc18> in <module>
#       3 urls = "//upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931958%29.svg/23px-Flag_of_France_%281794%E2%80%931815%2C_1830%E2%80%931958%29.svg.png"
#       4 trys = requests.get('https:'+urls)
# ----> 5 img = Image.open(BytesIO(trys.content))
#       6 img
#
# NameError: name 'Image' is not defined

# %%
for i in a.select('.flagicon')[0]:
    print(i['src'])

# %%
flag_link = []
error = []
try:
    for i in a.select('.flagicon'):
        for j in i:
            print(j['srcset'])
except:
    error.append(i)

# %%
for i in a.select('.flagicon'):
        for j in i:
            print(j['srcset'][0])

# %%
error

# %%
d = data.find_all("span", {'class':'datasortkey'})

# %%
d[0]['data-sort-value']

# %%
countries = []
for i in d:
    countries.append(i['data-sort-value'])

# %%
countries
